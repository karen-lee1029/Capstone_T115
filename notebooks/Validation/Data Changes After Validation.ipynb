-- %% [markdown]
-- Update course, curriculum, and academic organisation fields so that the same course appearing in the student table has the same key and hash, and so on for the other two categories.
